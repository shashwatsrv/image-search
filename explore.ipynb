# %%
from PIL import Image

# %%
from models.embedder import embed_image,embed_text
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from models.embedder import embed_image,embed_text
#
# ImportError: cannot import name 'embed_image' from 'models.embedder' (C:\Users\HP\Desktop\image-search\models\embedder.py)
